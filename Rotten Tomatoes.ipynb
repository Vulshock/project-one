# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
# Study data files

# %%
movies = ("rotten_tomatoes_movies.csv")
tmdb = ("tmdb_movies_data.csv")
movie_data = pd.read_csv(movies)
tmdb_data = pd.read_csv(tmdb)
movie_data.head()
# Out:
#                      rotten_tomatoes_link  \
# 0                              /m/0814255
# 1                              /m/0878835
# 2                                   /m/10
# 3                 /m/1000013-12_angry_men
# 4  /m/1000079-20000_leagues_under_the_sea
#
#                                          Movie Title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  A teenager discovers he's the descendant of a ...
# 1  Kate has a lot on her mind. There's the ethics...
# 2  Blake Edwards' 10 stars Dudley Moore as George...
# 3  A Puerto Rican youth is on trial for murder, a...
# 4  This 1954 Disney version of Jules Verne's 20,0...
#
#                                    critics_consensus  \
# ...

# %%
tmdb_data.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                     Movie Title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
tmdb_data["Title Release"] = ""
tmdb_data["runtime"] = tmdb_data["runtime"].astype(str)
tmdb_data["Title Release"] = tmdb_data["Movie Title"] + " " + tmdb_data["runtime"] +".0"
tmdb_data.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                     Movie Title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
movie_data = movie_data.rename(columns={"rotten_tomatoes_link": "Link",
                                       "movie_info": "Movie Info", "studio_name": "Studio", "tomatometer_status": "Tomatometer Status",
                                       "tomatometer_rating": "Tomatometer Rating", "runtime_in_minutes": "Runtime", "in_theaters_date": "Theater Release", "audience_status": "Audience Status",
                                       "audience_rating": "Audience Rating", "audience_count": "Audience Count", "audience_top_critics_count": "Audience Top Critics Count",
                                       "audience_fresh_critics_count": " Audience Fresh Critics Count", "audience_rotten_critics_count": "Audience Rotten Critics Count"})
movie_data.head(3)
# Out:
#          Link                                        Movie Title  \
# 0  /m/0814255  Percy Jackson & the Olympians: The Lightning T...
# 1  /m/0878835                                        Please Give
# 2       /m/10                                                 10
#
#                                           Movie Info  \
# 0  A teenager discovers he's the descendant of a ...
# 1  Kate has a lot on her mind. There's the ethics...
# 2  Blake Edwards' 10 stars Dudley Moore as George...
#
#                                    critics_consensus  \
# 0  Though it may seem like just another Harry Pot...
# 1  Nicole Holofcener's newest might seem slight i...
# 2                                                NaN
#
#                                     poster_image_url rating  \
# 0  https://resizing.flixster.com/p1veUpQ4ktsSHtRu...     PG
# 1  https://resizing.flixster.com/0AbudQ4KsB4BeXSB...      R
# 2  https://resizing.flixster.com/mF0dxH6UTa0FdkMs...      R
#
# ...

# %%
temp=movie_data["Runtime"]
temp=temp+"added"
temp
# Out:
# 0         83.0added
# 1         90.0added
# 2        118.0added
# 3         95.0added
# 4        127.0added
#             ...
# 16633    104.0added
# 16634    108.0added
# 16635    142.0added
# 16636    139.0added
# 16637    117.0added
# Name: Runtime, Length: 16638, dtype: object

# %%
movie_data["Title Release"] = ""
movie_data["Runtime"] = movie_data["Runtime"].astype(str)
movie_data["Title Release"] = movie_data["Movie Title"] + " " + movie_data["Runtime"]
movie_data.head()
# Out:
#                                      Link  \
# 0                              /m/0814255
# 1                              /m/0878835
# 2                                   /m/10
# 3                 /m/1000013-12_angry_men
# 4  /m/1000079-20000_leagues_under_the_sea
#
#                                          Movie Title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           Movie Info  \
# 0  A teenager discovers he's the descendant of a ...
# 1  Kate has a lot on her mind. There's the ethics...
# 2  Blake Edwards' 10 stars Dudley Moore as George...
# 3  A Puerto Rican youth is on trial for murder, a...
# 4  This 1954 Disney version of Jules Verne's 20,0...
#
#                                    critics_consensus  \
# ...

# %%
combined_movie = pd.merge(movie_data, tmdb_data, how ='left', on='Title Release')

combined_movie
# Out:
#                                          Link  \
# 0                                  /m/0814255
# 1                                  /m/0878835
# 2                                       /m/10
# 3                     /m/1000013-12_angry_men
# 4      /m/1000079-20000_leagues_under_the_sea
# ...                                       ...
# 16639                            /m/zoot_suit
# 16640                             /m/zootopia
# 16641                      /m/zorba_the_greek
# 16642                                 /m/zulu
# 16643                            /m/zulu_dawn
#
#                                            Movie Title_x  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# ...

# %%
combined_movie = combined_movie.rename(columns={"budget": "Budget", "revenue": "Revenue"})
combined_movie = combined_movie.dropna(subset=['Budget', "Revenue"])
combined_movie.head()
# Out:
#                         Link Movie Title_x  \
# 1                 /m/0878835   Please Give
# 22      /m/10003925-dead_end      Dead End
# 30   /m/10004504-ultraviolet   Ultraviolet
# 42  /m/10005499-oliver_twist  Oliver Twist
# 55         /m/10006343-dirty         Dirty
#
#                                            Movie Info  \
# 1   Kate has a lot on her mind. There's the ethics...
# 22  A family making their annual Christmas pilgrim...
# 30  In the late 21st a disease called Hemophagia h...
# 42  Director Roman Polanski gives one of Charles D...
# 55  In a city ravaged by violent crime, the police...
#
#                                     critics_consensus  \
# 1   Nicole Holofcener's newest might seem slight i...
# 22                                                NaN
# 30  An incomprehensible and forgettable sci-fi thr...
# 42  Polanski's version of Dickens' classic won't h...
# 55  Dirty is an unoriginal L.A. cop drama that wea...
#
# ...

# %%
refined_movie_data = combined_movie[["Movie Title_x", "Studio","Theater Release","Budget", "Revenue", "Tomatometer Status", "Tomatometer Rating", "Audience Status", "Audience Rating", "Audience Count"]]
refined_movie_data
# Out:
#                                            Movie Title_x  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# 16639                                          Zoot Suit
# 16640                                           Zootopia
# 16641                                    Zorba the Greek
# 16642                                               Zulu
# 16643                                          Zulu Dawn
#
#                               Studio Theater Release     Budget  Revenue  \
# 0                   20th Century Fox       2/12/2010        NaN      NaN
# 1             Sony Pictures Classics       4/30/2010  3000000.0      0.0
# ...

# %%
# refined_movie_data = refined_movie_data.drop_duplicates(subset:)
# refined_movie_data

# %%
Disney = refined_movie_data[(refined_movie_data["Studio"]== "Disney")]

Disney
